# %%
# Importing modules 
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import cv2

from keras.utils import to_categorical
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,Activation,MaxPooling2D
from keras.models import Sequential
from keras.models import load_model
from sklearn.model_selection import train_test_split

np.random.seed(1)

# %%
# Processing training data
# -> appending images in a list 'train_images'
# -> appending labels in a list 'train_labels'

train_images = []       
train_labels = []
shape = (100,100)  
train_path = 'DataExtended/train_zip/train'

for filename in os.listdir('DataExtended/train_zip/train'):
    if filename.split('.')[1] == 'jpg':
        img = cv2.imread(os.path.join(train_path,filename))
        
        try:
            # Resize all images to a specific shape
            img = cv2.resize(img,shape)

            # Spliting file names and storing the labels for image in list
            train_labels.append(filename.split('_')[0])

            train_images.append(img)
        except:
            pass
# Converting labels into One Hot encoded sparse matrix
train_labels = pd.get_dummies(train_labels).values

# Converting train_images to array
train_images = np.array(train_images)

# Splitting Training data into train and validation dataset
x_train,x_val,y_train,y_val = train_test_split(train_images,train_labels,random_state=1)

# %%
# Processing testing data
# -> appending images in a list 'test_images'
# -> appending labels in a list 'test_labels'
# The test data contains labels as well also we are appending it to a list but we are'nt going to use it while training.

test_images = []
test_labels = []
test_path = 'DataExtended/test_zip/test'

for filename in os.listdir('DataExtended/test_zip/test'):
    if filename.split('.')[1] == 'jpg':
        img = cv2.imread(os.path.join(test_path,filename))
        
        # Spliting file names and storing the labels for image in list
        test_labels.append(filename.split('_')[0])
        
        # Resize all images to a specific shape
        img = cv2.resize(img,shape)
        
        test_images.append(img)
        
# Converting test_images to array
test_images = np.array(test_images)

# %%
# Visualizing Training data
print(train_labels[0])
plt.imshow(train_images[0],cm)
# Out:
# [0 0 1]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-03faa92ff4d7> in <module>
#       1 # Visualizing Training data
#       2 print(train_labels[0])
# ----> 3 plt.imshow(train_images[0],cm)
#
# NameError: name 'cm' is not defined

# %%
# Visualizing Training data
print(train_labels[4])
plt.imshow(train_images[4])
# Out:
# [0 0 1]

# %%
#Building model 1 using customized convolutional and pooling layers

model = Sequential()

#input_shape is 100*100 since thats the dimension of each of the fruit images
model.add(Conv2D(filters = 32, kernel_size = 2,input_shape=(100,100,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 32,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 64,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 128,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

# specifying parameters for fully connected layer
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(150))
model.add(Activation('relu'))
model.add(Dropout(0.4))
model.add(Dense(3,activation = 'softmax'))

# %%
# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 100, 100, 32)      416
# _________________________________________________________________
# activation (Activation)      (None, 100, 100, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        4128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 128)       32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 150)               691350
# _________________________________________________________________
# activation_1 (Activation)    (None, 150)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 453
# =================================================================
# Total params: 737,499
# Trainable params: 737,499
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training takes 10 minutes     Hold your horses!!!!!

# %%
from keras.optimizers import SGD, Adam, RMSprop

optimizer = Adam()
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
# fitting model using above defined layers 
CNN_model = model.fit(x_train,y_train,epochs=50,batch_size=50,validation_data=(x_val,y_val),
        verbose=2, shuffle=True)
# Out:
# Epoch 1/50
# 5/5 - 1s - loss: 87.2706 - accuracy: 0.3574 - val_loss: 11.7209 - val_accuracy: 0.3253
# Epoch 2/50
# 5/5 - 1s - loss: 9.1413 - accuracy: 0.3614 - val_loss: 1.9580 - val_accuracy: 0.4940
# Epoch 3/50
# 5/5 - 1s - loss: 1.7566 - accuracy: 0.4538 - val_loss: 0.9795 - val_accuracy: 0.4940
# Epoch 4/50
# 5/5 - 1s - loss: 1.2489 - accuracy: 0.4297 - val_loss: 0.8815 - val_accuracy: 0.6747
# Epoch 5/50
# 5/5 - 1s - loss: 0.8939 - accuracy: 0.5582 - val_loss: 0.6337 - val_accuracy: 0.7952
# Epoch 6/50
# 5/5 - 1s - loss: 0.7370 - accuracy: 0.6867 - val_loss: 0.4883 - val_accuracy: 0.8193
# Epoch 7/50
# 5/5 - 1s - loss: 0.6512 - accuracy: 0.7028 - val_loss: 0.3845 - val_accuracy: 0.9036
# Epoch 8/50
# 5/5 - 1s - loss: 0.4565 - accuracy: 0.8353 - val_loss: 0.2847 - val_accuracy: 0.9398
# Epoch 9/50
# 5/5 - 1s - loss: 0.3594 - accuracy: 0.8675 - val_loss: 0.2363 - val_accuracy: 0.9518
# Epoch 10/50
# 5/5 - 1s - loss: 0.2645 - accuracy: 0.9157 - val_loss: 0.2554 - val_accuracy: 0.9398
# Epoch 11/50
# 5/5 - 1s - loss: 0.2279 - accuracy: 0.9157 - val_loss: 0.2125 - val_accuracy: 0.9157
# Epoch 12/50
# 5/5 - 1s - loss: 0.2161 - accuracy: 0.9398 - val_loss: 0.2467 - val_accuracy: 0.9518
# Epoch 13/50
# 5/5 - 1s - loss: 0.1637 - accuracy: 0.9438 - val_loss: 0.1973 - val_accuracy: 0.9639
# Epoch 14/50
# 5/5 - 1s - loss: 0.1593 - accuracy: 0.9357 - val_loss: 0.2564 - val_accuracy: 0.9398
# Epoch 15/50
# 5/5 - 1s - loss: 0.1362 - accuracy: 0.9598 - val_loss: 0.2616 - val_accuracy: 0.9398
# Epoch 16/50
# 5/5 - 1s - loss: 0.1375 - accuracy: 0.9438 - val_loss: 0.2385 - val_accuracy: 0.9398
# Epoch 17/50
# 5/5 - 1s - loss: 0.0948 - accuracy: 0.9639 - val_loss: 0.2143 - val_accuracy: 0.9518
# Epoch 18/50
# 5/5 - 1s - loss: 0.0727 - accuracy: 0.9799 - val_loss: 0.2350 - val_accuracy: 0.9639
# Epoch 19/50
# 5/5 - 1s - loss: 0.0475 - accuracy: 0.9880 - val_loss: 0.2463 - val_accuracy: 0.9518
# Epoch 20/50
# 5/5 - 1s - loss: 0.0826 - accuracy: 0.9759 - val_loss: 0.2361 - val_accuracy: 0.9759
# Epoch 21/50
# 5/5 - 1s - loss: 0.0471 - accuracy: 0.9920 - val_loss: 0.2334 - val_accuracy: 0.9759
# Epoch 22/50
# 5/5 - 1s - loss: 0.0766 - accuracy: 0.9759 - val_loss: 0.1836 - val_accuracy: 0.9639
# Epoch 23/50
# 5/5 - 1s - loss: 0.0718 - accuracy: 0.9839 - val_loss: 0.3176 - val_accuracy: 0.9639
# Epoch 24/50
# 5/5 - 1s - loss: 0.0450 - accuracy: 0.9920 - val_loss: 0.2713 - val_accuracy: 0.9759
# Epoch 25/50
# 5/5 - 1s - loss: 0.0649 - accuracy: 0.9799 - val_loss: 0.1994 - val_accuracy: 0.9759
# Epoch 26/50
# 5/5 - 1s - loss: 0.1669 - accuracy: 0.9558 - val_loss: 0.3973 - val_accuracy: 0.9036
# Epoch 27/50
# 5/5 - 1s - loss: 0.3665 - accuracy: 0.8916 - val_loss: 0.3715 - val_accuracy: 0.8554
# Epoch 28/50
# 5/5 - 1s - loss: 0.1882 - accuracy: 0.9398 - val_loss: 0.3529 - val_accuracy: 0.9398
# Epoch 29/50
# 5/5 - 1s - loss: 0.1693 - accuracy: 0.9558 - val_loss: 0.2085 - val_accuracy: 0.9518
# Epoch 30/50
# 5/5 - 1s - loss: 0.0956 - accuracy: 0.9679 - val_loss: 0.1908 - val_accuracy: 0.9518
# Epoch 31/50
# 5/5 - 1s - loss: 0.0786 - accuracy: 0.9719 - val_loss: 0.2137 - val_accuracy: 0.9759
# Epoch 32/50
# 5/5 - 1s - loss: 0.0343 - accuracy: 0.9920 - val_loss: 0.2938 - val_accuracy: 0.9759
# Epoch 33/50
# 5/5 - 1s - loss: 0.0331 - accuracy: 0.9839 - val_loss: 0.3257 - val_accuracy: 0.9759
# Epoch 34/50
# 5/5 - 1s - loss: 0.0261 - accuracy: 0.9880 - val_loss: 0.2978 - val_accuracy: 0.9880
# Epoch 35/50
# 5/5 - 1s - loss: 0.0397 - accuracy: 0.9920 - val_loss: 0.3052 - val_accuracy: 0.9880
# Epoch 36/50
# 5/5 - 1s - loss: 0.0432 - accuracy: 0.9799 - val_loss: 0.2175 - val_accuracy: 0.9759
# Epoch 37/50
# 5/5 - 1s - loss: 0.0309 - accuracy: 0.9839 - val_loss: 0.2299 - val_accuracy: 0.9880
# Epoch 38/50
# 5/5 - 1s - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.3083 - val_accuracy: 0.9759
# Epoch 39/50
# 5/5 - 1s - loss: 0.0312 - accuracy: 0.9960 - val_loss: 0.3732 - val_accuracy: 0.9518
# Epoch 40/50
# 5/5 - 1s - loss: 0.0218 - accuracy: 0.9920 - val_loss: 0.3306 - val_accuracy: 0.9759
# Epoch 41/50
# 5/5 - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2877 - val_accuracy: 0.9880
# Epoch 42/50
# 5/5 - 1s - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.2958 - val_accuracy: 0.9880
# Epoch 43/50
# 5/5 - 1s - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.3422 - val_accuracy: 0.9759
# Epoch 44/50
# 5/5 - 1s - loss: 0.0093 - accuracy: 0.9960 - val_loss: 0.3434 - val_accuracy: 0.9759
# Epoch 45/50
# 5/5 - 1s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 0.3130 - val_accuracy: 0.9880
# Epoch 46/50
# 5/5 - 1s - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.3170 - val_accuracy: 0.9880
# Epoch 47/50
# 5/5 - 1s - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.3291 - val_accuracy: 0.9880
# Epoch 48/50
# 5/5 - 1s - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.4013 - val_accuracy: 0.9759
# Epoch 49/50
# 5/5 - 1s - loss: 0.0073 - accuracy: 0.9960 - val_loss: 0.3522 - val_accuracy: 0.9880
# Epoch 50/50
# 5/5 - 1s - loss: 0.0062 - accuracy: 0.9960 - val_loss: 0.3856 - val_accuracy: 0.9880

# %%
#Saving the model
model.save('newsmodel.h5')
#loss: 0.0928 - acc: 0.9333 - val_loss: 0.7667 - val_acc: 0.8333

# %%
#Loading the model
model = load_model('newmodel.h5')

# %%
# Evaluating model on validation data
evaluate = model.evaluate(x_val,y_val)
print(evaluate)
# Out:
# 3/3 [==============================] - 0s 18ms/step - loss: 0.3856 - accuracy: 0.9880
# [0.38564807176589966, 0.9879518151283264]

# %%
# Testing predictions and the actual label
checkImage = test_images[0:1]
checklabel = test_labels[0:1]

predict = model.predict(np.array(checkImage))

output = { 0:'apple',1:'banana',2:'orange'}

print("Actual :- ",checklabel)
print("Predicted :- ",output[np.argmax(predict)])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b4c60859286c> in <module>
#       1 # Testing predictions and the actual label
# ----> 2 checkImage = test_images[0:1]
#       3 checklabel = test_labels[0:1]
#       4
#       5 predict = model.predict(np.array(checkImage))
#
# NameError: name 'test_images' is not defined

# %% [markdown]
# # Testing by Ramkishor

# %%
def show_image(index):
    print(test_labels[index])
    #plt.imshow(test_images[index])
    cv2.imshow('win',test_images[index])
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# Testing predictions and the actual label
def test(index):
    checkImage = test_images[index:index+1]
    checklabel = test_labels[index:index+1]

    predict = model.predict(np.array(checkImage))

    output = { 0:'apple',1:'banana',2:'orange'}
    #print("Actual :- ",checklabel)
    #print("Predicted :- ",output[np.argmax(predict)])
    
    return checklabel,output[np.argmax(predict)]
    #show_image(index)

# %%
correct_count = 0
incorrect_count = 0
for i in range(10,len(test_images)):
    Actual,Predicted = test(i)

    
    if Actual[0] == Predicted:
        correct_count+=1
        #print(f"{Actual[0]} is predicted as {Predicted}")
        #show_image(i)
    else:
        incorrect_count+=1
        #print(f"{Actual[0]} is predicted as {Predicted}")
        #show_image(i)
print()
print(f"correct_count = {correct_count}")
print(f"incorrect_count = {incorrect_count}")
# Out:
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
#
# correct_count = 45
# incorrect_count = 0

# %%
NewTestPath = '/home/ram/Mywork/Deep-Learning-Food-Classification/DataExtended/NewTestData'
my_test_images=[]
my_test_labels=[]

for filename in os.listdir(NewTestPath):
        img = cv2.imread(os.path.join(NewTestPath,filename))
        
        # Resize all images to a specific shape
        img = cv2.resize(img,shape)
                
        # Spliting file names and storing the labels for image in list
        my_test_labels.append(filename.split('_')[0])
        

        my_test_images.append(img)


def test(index):
    checkImage = my_test_images[index:index+1]
    Actual = my_test_labels[index]
    predict = model.predict(np.array(checkImage))

    output = { 0:'apple',1:'banana',2:'orange'}
    #print("Actual :- ",checklabel)
    #print("Predicted :- ",output[np.argmax(predict)])
    
    return Actual,output[np.argmax(predict)]
    #show_image(index)
def show_image(index):
    #plt.imshow(test_images[index])
    cv2.imshow('win',my_test_images[i])
    cv2.waitKey(0)
    cv2.destroyAllWindows()


for i in range(len(my_test_images)):
    Actual,Predicted = test(i)
    print(f"{Actual} is predicted as {Predicted}")
    show_image(i)
# Out:
# orange is predicted as apple
# banana is predicted as banana
# orange is predicted as banana
# orange is predicted as banana
# banana is predicted as banana
# orange is predicted as banana
# banana is predicted as apple
# apple is predicted as apple
# banana is predicted as banana
# orange is predicted as banana
# banana is predicted as orange
# apple is predicted as apple
