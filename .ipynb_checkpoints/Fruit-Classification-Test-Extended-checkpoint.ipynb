# %%
# Importing modules 
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import cv2

from keras.utils import to_categorical
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,Activation,MaxPooling2D
from keras.models import Sequential
from keras.models import load_model
from sklearn.model_selection import train_test_split

np.random.seed(1)

# %%
# Processing training data
# -> appending images in a list 'train_images'
# -> appending labels in a list 'train_labels'

train_images = []       
train_labels = []
shape = (100,100)  
train_path = 'DataExtended/train_zip/train'

for filename in os.listdir('DataExtended/train_zip/train'):
    if filename.split('.')[1] == 'jpg':
        img = cv2.imread(os.path.join(train_path,filename))
        
        try:
            # Resize all images to a specific shape
            img = cv2.resize(img,shape)

            # Spliting file names and storing the labels for image in list
            train_labels.append(filename.split('_')[0])

            train_images.append(img)
        except:
            pass
# Converting labels into One Hot encoded sparse matrix
train_labels = pd.get_dummies(train_labels).values

# Converting train_images to array
train_images = np.array(train_images)

# Splitting Training data into train and validation dataset
x_train,x_val,y_train,y_val = train_test_split(train_images,train_labels,random_state=1)

# %%
# Processing testing data
# -> appending images in a list 'test_images'
# -> appending labels in a list 'test_labels'
# The test data contains labels as well also we are appending it to a list but we are'nt going to use it while training.

test_images = []
test_labels = []
test_path = 'DataExtended/test_zip/test'

for filename in os.listdir('DataExtended/test_zip/test'):
    if filename.split('.')[1] == 'jpg':
        img = cv2.imread(os.path.join(test_path,filename))
        
        # Spliting file names and storing the labels for image in list
        test_labels.append(filename.split('_')[0])
        
        # Resize all images to a specific shape
        img = cv2.resize(img,shape)
        
        test_images.append(img)
        
# Converting test_images to array
test_images = np.array(test_images)

# %%
# Visualizing Training data
print(train_labels[0])
plt.imshow(train_images[0])
# Out:
# [0 0 1]

# %%
# Visualizing Training data
print(train_labels[4])
plt.imshow(train_images[4])
# Out:
# [1 0 0]

# %%
#Building model 1 using customized convolutional and pooling layers

model = Sequential()

#input_shape is 100*100 since thats the dimension of each of the fruit images
model.add(Conv2D(filters = 32, kernel_size = 2,input_shape=(100,100,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 32,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 64,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 128,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

# specifying parameters for fully connected layer
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(150))
model.add(Activation('relu'))
model.add(Dropout(0.4))
model.add(Dense(3,activation = 'softmax'))

# %%
# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 100, 100, 32)      416
# _________________________________________________________________
# activation (Activation)      (None, 100, 100, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        4128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 128)       32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 150)               691350
# _________________________________________________________________
# activation_1 (Activation)    (None, 150)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 453
# =================================================================
# Total params: 737,499
# Trainable params: 737,499
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training takes 10 minutes     Hold your horses!!!!!

# %%
from keras.optimizers import SGD, Adam, RMSprop

optimizer = Adam()
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
# fitting model using above defined layers 
CNN_model = model.fit(x_train,y_train,epochs=50,batch_size=50,validation_data=(x_val,y_val),
        verbose=2, shuffle=True)
# Out:
# Epoch 1/50
# 6/6 - 1s - loss: 37.0594 - accuracy: 0.3296 - val_loss: 4.1331 - val_accuracy: 0.3077
# Epoch 2/50
# 6/6 - 1s - loss: 3.8391 - accuracy: 0.3889 - val_loss: 1.8309 - val_accuracy: 0.2857
# Epoch 3/50
# 6/6 - 1s - loss: 1.5836 - accuracy: 0.4407 - val_loss: 1.1592 - val_accuracy: 0.3736
# Epoch 4/50
# 6/6 - 1s - loss: 1.1039 - accuracy: 0.4481 - val_loss: 1.0205 - val_accuracy: 0.5385
# Epoch 5/50
# 6/6 - 1s - loss: 0.9922 - accuracy: 0.4778 - val_loss: 0.9356 - val_accuracy: 0.5714
# Epoch 6/50
# 6/6 - 1s - loss: 0.9336 - accuracy: 0.5593 - val_loss: 0.8347 - val_accuracy: 0.6484
# Epoch 7/50
# 6/6 - 1s - loss: 0.7978 - accuracy: 0.6741 - val_loss: 0.6943 - val_accuracy: 0.6923
# Epoch 8/50
# 6/6 - 1s - loss: 0.7148 - accuracy: 0.6815 - val_loss: 0.4851 - val_accuracy: 0.8462
# Epoch 9/50
# 6/6 - 1s - loss: 0.4662 - accuracy: 0.8148 - val_loss: 0.3490 - val_accuracy: 0.8242
# Epoch 10/50
# 6/6 - 1s - loss: 0.3727 - accuracy: 0.8481 - val_loss: 0.2704 - val_accuracy: 0.9121
# Epoch 11/50
# 6/6 - 1s - loss: 0.3338 - accuracy: 0.8889 - val_loss: 0.3771 - val_accuracy: 0.8901
# Epoch 12/50
# 6/6 - 1s - loss: 0.3526 - accuracy: 0.8778 - val_loss: 0.2440 - val_accuracy: 0.8901
# Epoch 13/50
# 6/6 - 1s - loss: 0.2938 - accuracy: 0.9185 - val_loss: 0.2519 - val_accuracy: 0.9121
# Epoch 14/50
# 6/6 - 1s - loss: 0.2658 - accuracy: 0.9037 - val_loss: 0.1803 - val_accuracy: 0.9451
# Epoch 15/50
# 6/6 - 1s - loss: 0.1832 - accuracy: 0.9556 - val_loss: 0.2075 - val_accuracy: 0.9231
# Epoch 16/50
# 6/6 - 1s - loss: 0.1569 - accuracy: 0.9630 - val_loss: 0.1922 - val_accuracy: 0.9341
# Epoch 17/50
# 6/6 - 1s - loss: 0.1857 - accuracy: 0.9407 - val_loss: 0.1878 - val_accuracy: 0.9451
# Epoch 18/50
# 6/6 - 1s - loss: 0.1915 - accuracy: 0.9444 - val_loss: 0.2135 - val_accuracy: 0.9011
# Epoch 19/50
# 6/6 - 1s - loss: 0.1702 - accuracy: 0.9630 - val_loss: 0.2195 - val_accuracy: 0.9231
# Epoch 20/50
# 6/6 - 1s - loss: 0.1867 - accuracy: 0.9407 - val_loss: 0.1820 - val_accuracy: 0.9231
# Epoch 21/50
# 6/6 - 1s - loss: 0.1560 - accuracy: 0.9407 - val_loss: 0.2993 - val_accuracy: 0.9451
# Epoch 22/50
# 6/6 - 1s - loss: 0.1605 - accuracy: 0.9481 - val_loss: 0.1363 - val_accuracy: 0.9451
# Epoch 23/50
# 6/6 - 1s - loss: 0.1356 - accuracy: 0.9667 - val_loss: 0.1861 - val_accuracy: 0.9231
# Epoch 24/50
# 6/6 - 1s - loss: 0.1120 - accuracy: 0.9667 - val_loss: 0.1459 - val_accuracy: 0.9341
# Epoch 25/50
# 6/6 - 1s - loss: 0.0921 - accuracy: 0.9815 - val_loss: 0.1506 - val_accuracy: 0.9451
# Epoch 26/50
# 6/6 - 1s - loss: 0.0799 - accuracy: 0.9815 - val_loss: 0.1510 - val_accuracy: 0.9451
# Epoch 27/50
# 6/6 - 1s - loss: 0.0515 - accuracy: 0.9778 - val_loss: 0.3004 - val_accuracy: 0.9341
# Epoch 28/50
# 6/6 - 1s - loss: 0.1279 - accuracy: 0.9593 - val_loss: 0.4503 - val_accuracy: 0.8352
# Epoch 29/50
# 6/6 - 1s - loss: 0.3414 - accuracy: 0.9000 - val_loss: 0.4273 - val_accuracy: 0.8901
# Epoch 30/50
# 6/6 - 1s - loss: 0.2026 - accuracy: 0.9296 - val_loss: 0.2280 - val_accuracy: 0.8901
# Epoch 31/50
# 6/6 - 1s - loss: 0.2137 - accuracy: 0.9296 - val_loss: 0.2403 - val_accuracy: 0.9121
# Epoch 32/50
# 6/6 - 1s - loss: 0.1365 - accuracy: 0.9741 - val_loss: 0.1162 - val_accuracy: 0.9560
# Epoch 33/50
# 6/6 - 1s - loss: 0.0741 - accuracy: 0.9889 - val_loss: 0.1299 - val_accuracy: 0.9451
# Epoch 34/50
# 6/6 - 1s - loss: 0.0489 - accuracy: 0.9889 - val_loss: 0.1189 - val_accuracy: 0.9451
# Epoch 35/50
# 6/6 - 1s - loss: 0.0422 - accuracy: 0.9815 - val_loss: 0.2217 - val_accuracy: 0.9341
# Epoch 36/50
# 6/6 - 1s - loss: 0.0506 - accuracy: 0.9741 - val_loss: 0.1662 - val_accuracy: 0.9451
# Epoch 37/50
# 6/6 - 1s - loss: 0.0455 - accuracy: 0.9815 - val_loss: 0.1513 - val_accuracy: 0.9451
# Epoch 38/50
# 6/6 - 1s - loss: 0.1618 - accuracy: 0.9519 - val_loss: 0.2148 - val_accuracy: 0.9341
# Epoch 39/50
# 6/6 - 1s - loss: 0.1119 - accuracy: 0.9667 - val_loss: 0.1384 - val_accuracy: 0.9231
# Epoch 40/50
# 6/6 - 1s - loss: 0.0467 - accuracy: 0.9778 - val_loss: 0.1132 - val_accuracy: 0.9560
# Epoch 41/50
# 6/6 - 1s - loss: 0.0464 - accuracy: 0.9889 - val_loss: 0.1168 - val_accuracy: 0.9451
# Epoch 42/50
# 6/6 - 1s - loss: 0.0227 - accuracy: 0.9963 - val_loss: 0.1510 - val_accuracy: 0.9451
# Epoch 43/50
# 6/6 - 1s - loss: 0.0091 - accuracy: 0.9963 - val_loss: 0.1343 - val_accuracy: 0.9231
# Epoch 44/50
# 6/6 - 1s - loss: 0.0159 - accuracy: 0.9963 - val_loss: 0.1573 - val_accuracy: 0.9231
# Epoch 45/50
# 6/6 - 1s - loss: 0.0182 - accuracy: 0.9926 - val_loss: 0.2731 - val_accuracy: 0.9451
# Epoch 46/50
# 6/6 - 1s - loss: 0.0262 - accuracy: 0.9889 - val_loss: 0.1874 - val_accuracy: 0.9231
# Epoch 47/50
# 6/6 - 1s - loss: 0.0327 - accuracy: 0.9926 - val_loss: 0.2462 - val_accuracy: 0.9341
# Epoch 48/50
# 6/6 - 1s - loss: 0.0181 - accuracy: 0.9926 - val_loss: 0.1912 - val_accuracy: 0.9231
# Epoch 49/50
# 6/6 - 1s - loss: 0.0108 - accuracy: 1.0000 - val_loss: 0.1716 - val_accuracy: 0.9231
# Epoch 50/50
# 6/6 - 1s - loss: 0.0166 - accuracy: 0.9926 - val_loss: 0.1649 - val_accuracy: 0.9341

# %%
#Saving the model
model.save('newmodel.h5')
#loss: 0.0928 - acc: 0.9333 - val_loss: 0.7667 - val_acc: 0.8333

# %%
#Loading the model
model = load_model('newmodel.h5')
history  = CNN_model

# %%
# Evaluating model on validation data
evaluate = model.evaluate(x_val,y_val)
print(evaluate)
# Out:
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1649 - accuracy: 0.9341
# [0.16490700840950012, 0.9340659379959106]

# %%
# Testing predictions and the actual label
checkImage = test_images[0:1]
checklabel = test_labels[0:1]

predict = model.predict(np.array(checkImage))

output = { 0:'apple',1:'banana',2:'orange'}

print("Actual :- ",checklabel)
print("Predicted :- ",output[np.argmax(predict)])
# Out:
# Actual :-  ['banana']
# Predicted :-  banana

# %% [markdown]
# # Testing by Ramkishor

# %%
def show_image(index):
    print(test_labels[index])
    #plt.imshow(test_images[index])
    cv2.imshow('win',test_images[index])
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# Testing predictions and the actual label
def test(index):
    checkImage = test_images[index:index+1]
    checklabel = test_labels[index:index+1]

    predict = model.predict(np.array(checkImage))

    output = { 0:'apple',1:'banana',2:'orange'}
    #print("Actual :- ",checklabel)
    #print("Predicted :- ",output[np.argmax(predict)])
    
    return checklabel,output[np.argmax(predict)]
    #show_image(index)

# %%
correct_count = 0
incorrect_count = 0
for i in range(10,len(test_images)):
    Actual,Predicted = test(i)

    
    if Actual[0] == Predicted:
        correct_count+=1
        print(f"{Actual[0]} is predicted as {Predicted}")
        show_image(i)
    else:
        incorrect_count+=1
        #print(f"{Actual[0]} is predicted as {Predicted}")
        #show_image(i)
print()
print(f"correct_count = {correct_count}")
print(f"incorrect_count = {incorrect_count}")
# Out:
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
#
# correct_count = 49
# incorrect_count = 0

# %%
NewTestPath = 'NewTestData'
my_test_images=[]
my_test_labels=[]

for filename in os.listdir(NewTestPath):
        img = cv2.imread(os.path.join(NewTestPath,filename))
        
        # Resize all images to a specific shape
        img = cv2.resize(img,shape)
                
        # Spliting file names and storing the labels for image in list
        my_test_labels.append(filename.split('_')[0])
        

        my_test_images.append(img)


def test(index):
    checkImage = my_test_images[index:index+1]
    Actual = my_test_labels[index]
    predict = model.predict(np.array(checkImage))

    output = { 0:'apple',1:'banana',2:'orange'}
    #print("Actual :- ",checklabel)
    #print("Predicted :- ",output[np.argmax(predict)])
    
    return Actual,output[np.argmax(predict)]
    #show_image(index)
def show_image(index):
    #plt.imshow(test_images[index])
    cv2.imshow('win',my_test_images[i])
    cv2.waitKey(0)
    cv2.destroyAllWindows()


for i in range(len(my_test_images)):
    Actual,Predicted = test(i)
    print(f"{Actual} is predicted as {Predicted}")
    show_image(i)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-17-1ecb904ed584> in <module>
#      18 img = cv2.imread('/home/ram/Desktop/imagess.jpeg')
#      19 my_test_images=[]
# ---> 20 img = cv2.resize(img,shape)
#      21 my_test_images.append(img)
#      22 img = cv2.imread('/home/ram/Desktop/images.jpeg')
#
# error: OpenCV(4.2.0) ../modules/imgproc/src/resize.cpp:4045: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
