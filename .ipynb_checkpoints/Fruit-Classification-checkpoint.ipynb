# %%
# Importing modules 
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import cv2

from keras.utils import to_categorical
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout
from keras.models import Sequential
from keras.models import load_model
from sklearn.model_selection import train_test_split

np.random.seed(1)

# %%
# Processing training data
# -> appending images in a list 'train_images'
# -> appending labels in a list 'train_labels'

train_images = []       
train_labels = []
shape = (200,200)  
train_path = 'Data/train_zip/train'

for filename in os.listdir('Data/train_zip/train'):
    if filename.split('.')[1] == 'jpg':
        img = cv2.imread(os.path.join(train_path,filename))
        
        # Spliting file names and storing the labels for image in list
        train_labels.append(filename.split('_')[0])
        
        # Resize all images to a specific shape
        img = cv2.resize(img,shape)
        
        train_images.append(img)

# Converting labels into One Hot encoded sparse matrix
train_labels = pd.get_dummies(train_labels).values

# Converting train_images to array
train_images = np.array(train_images)

# Splitting Training data into train and validation dataset
x_train,x_val,y_train,y_val = train_test_split(train_images,train_labels,random_state=1)

# %%
# Processing testing data
# -> appending images in a list 'test_images'
# -> appending labels in a list 'test_labels'
# The test data contains labels as well also we are appending it to a list but we are'nt going to use it while training.

test_images = []
test_labels = []
shape = (200,200)
test_path = 'Data/test_zip/test'

for filename in os.listdir('Data/test_zip/test'):
    if filename.split('.')[1] == 'jpg':
        img = cv2.imread(os.path.join(test_path,filename))
        
        # Spliting file names and storing the labels for image in list
        test_labels.append(filename.split('_')[0])
        
        # Resize all images to a specific shape
        img = cv2.resize(img,shape)
        
        test_images.append(img)
        
# Converting test_images to array
test_images = np.array(test_images)

# %%
# Visualizing Training data
print(train_labels[0])
plt.imshow(train_images[0])
# Out:
# [1 0 0 0]

# %%
# Visualizing Training data
print(train_labels[4])
plt.imshow(train_images[4])
# Out:
# [1 0 0 0]

# %%
# Creating a Sequential model
model= Sequential()
model.add(Conv2D(kernel_size=(3,3), filters=32, activation='tanh', input_shape=(200,200,3,)))
model.add(Conv2D(filters=30,kernel_size = (3,3),activation='tanh'))
model.add(MaxPool2D(2,2))
model.add(Conv2D(filters=30,kernel_size = (3,3),activation='tanh'))
model.add(MaxPool2D(2,2))
model.add(Conv2D(filters=30,kernel_size = (3,3),activation='tanh'))

model.add(Flatten())

model.add(Dense(20,activation='relu'))
model.add(Dense(15,activation='relu'))
model.add(Dense(4,activation = 'softmax'))
    
model.compile(
              loss='categorical_crossentropy', 
              metrics=['acc'],
              optimizer='adam'
             )

# %%
# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 198, 198, 32)      896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 196, 196, 30)      8670
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 98, 98, 30)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 96, 96, 30)        8130
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 48, 48, 30)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 46, 46, 30)        8130
# _________________________________________________________________
# flatten (Flatten)            (None, 63480)             0
# _________________________________________________________________
# dense (Dense)                (None, 20)                1269620
# _________________________________________________________________
# dense_1 (Dense)              (None, 15)                315
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 64
# =================================================================
# Total params: 1,295,825
# Trainable params: 1,295,825
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training takes 10 minutes     Hold your horses!!!!!

# %%
# Training the model
history = model.fit(x_train,y_train,epochs=50,batch_size=50,validation_data=(x_val,y_val))
# Out:
# Epoch 1/50
# 4/4 [==============================] - 10s 3s/step - loss: 5.5113 - acc: 0.2556 - val_loss: 6.9802 - val_acc: 0.3500
# Epoch 2/50
# 4/4 [==============================] - 10s 2s/step - loss: 4.0866 - acc: 0.3611 - val_loss: 0.9842 - val_acc: 0.5000
# Epoch 3/50
# 4/4 [==============================] - 10s 2s/step - loss: 1.4234 - acc: 0.5000 - val_loss: 1.3067 - val_acc: 0.4000
# Epoch 4/50
# 4/4 [==============================] - 10s 3s/step - loss: 1.2550 - acc: 0.4444 - val_loss: 1.3049 - val_acc: 0.4000
# Epoch 5/50
# 4/4 [==============================] - 10s 3s/step - loss: 1.1393 - acc: 0.4500 - val_loss: 1.1081 - val_acc: 0.4667
# Epoch 6/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.9950 - acc: 0.5333 - val_loss: 1.0345 - val_acc: 0.5333
# Epoch 7/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.9144 - acc: 0.5722 - val_loss: 1.0127 - val_acc: 0.5500
# Epoch 8/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.8204 - acc: 0.5722 - val_loss: 0.9389 - val_acc: 0.5667
# Epoch 9/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.6920 - acc: 0.7056 - val_loss: 0.8118 - val_acc: 0.7833
# Epoch 10/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.6287 - acc: 0.8500 - val_loss: 0.8373 - val_acc: 0.6333
# Epoch 11/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.6903 - acc: 0.6722 - val_loss: 0.9008 - val_acc: 0.6167
# Epoch 12/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.6012 - acc: 0.7167 - val_loss: 0.6999 - val_acc: 0.7000
# Epoch 13/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.4807 - acc: 0.8556 - val_loss: 0.8647 - val_acc: 0.7833
# Epoch 14/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.4425 - acc: 0.8556 - val_loss: 0.7183 - val_acc: 0.7500
# Epoch 15/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.3671 - acc: 0.8833 - val_loss: 0.5933 - val_acc: 0.8000
# Epoch 16/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.3129 - acc: 0.9222 - val_loss: 0.6571 - val_acc: 0.8333
# Epoch 17/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.3040 - acc: 0.9167 - val_loss: 0.6254 - val_acc: 0.7833
# Epoch 18/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.3036 - acc: 0.8889 - val_loss: 0.7804 - val_acc: 0.8167
# Epoch 19/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.2698 - acc: 0.9167 - val_loss: 0.6160 - val_acc: 0.7500
# Epoch 20/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.3079 - acc: 0.8944 - val_loss: 0.5415 - val_acc: 0.8167
# Epoch 21/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.2136 - acc: 0.9278 - val_loss: 0.6631 - val_acc: 0.7833
# Epoch 22/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1940 - acc: 0.9500 - val_loss: 0.6521 - val_acc: 0.8333
# Epoch 23/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1748 - acc: 0.9222 - val_loss: 0.6213 - val_acc: 0.8000
# Epoch 24/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1705 - acc: 0.9389 - val_loss: 0.6397 - val_acc: 0.8500
# Epoch 25/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.1709 - acc: 0.9667 - val_loss: 0.6219 - val_acc: 0.8333
# Epoch 26/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.1631 - acc: 0.9333 - val_loss: 0.7256 - val_acc: 0.8333
# Epoch 27/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1533 - acc: 0.9444 - val_loss: 0.6840 - val_acc: 0.8500
# Epoch 28/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1481 - acc: 0.9667 - val_loss: 0.5548 - val_acc: 0.8167
# Epoch 29/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1463 - acc: 0.9389 - val_loss: 0.5795 - val_acc: 0.8167
# Epoch 30/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1454 - acc: 0.9500 - val_loss: 0.6239 - val_acc: 0.8667
# Epoch 31/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1332 - acc: 0.9722 - val_loss: 0.6481 - val_acc: 0.7333
# Epoch 32/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1444 - acc: 0.9500 - val_loss: 0.7046 - val_acc: 0.8333
# Epoch 33/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.1363 - acc: 0.9611 - val_loss: 0.7310 - val_acc: 0.8167
# Epoch 34/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.1263 - acc: 0.9389 - val_loss: 0.5898 - val_acc: 0.8000
# Epoch 35/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.1262 - acc: 0.9611 - val_loss: 0.6131 - val_acc: 0.8000
# Epoch 36/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1272 - acc: 0.9889 - val_loss: 0.6200 - val_acc: 0.8167
# Epoch 37/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1175 - acc: 0.9722 - val_loss: 0.6570 - val_acc: 0.8000
# Epoch 38/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1184 - acc: 0.9333 - val_loss: 0.7344 - val_acc: 0.8167
# Epoch 39/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.1145 - acc: 0.9611 - val_loss: 0.6685 - val_acc: 0.8333
# Epoch 40/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.1092 - acc: 0.9556 - val_loss: 0.6788 - val_acc: 0.7667
# Epoch 41/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1100 - acc: 0.9333 - val_loss: 0.6131 - val_acc: 0.8167
# Epoch 42/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1058 - acc: 0.9667 - val_loss: 0.6073 - val_acc: 0.8167
# Epoch 43/50
# 4/4 [==============================] - 11s 3s/step - loss: 0.1026 - acc: 0.9500 - val_loss: 0.6194 - val_acc: 0.8167
# Epoch 44/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.1027 - acc: 0.9278 - val_loss: 0.6341 - val_acc: 0.8333
# Epoch 45/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.1009 - acc: 0.9500 - val_loss: 0.6457 - val_acc: 0.8333
# Epoch 46/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.0978 - acc: 0.9444 - val_loss: 0.6415 - val_acc: 0.8167
# Epoch 47/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.0969 - acc: 0.9278 - val_loss: 0.6631 - val_acc: 0.8167
# Epoch 48/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.0958 - acc: 0.9722 - val_loss: 0.6944 - val_acc: 0.8333
# Epoch 49/50
# 4/4 [==============================] - 10s 3s/step - loss: 0.0938 - acc: 0.9278 - val_loss: 0.7249 - val_acc: 0.8333
# Epoch 50/50
# 4/4 [==============================] - 10s 2s/step - loss: 0.0928 - acc: 0.9333 - val_loss: 0.7667 - val_acc: 0.8333

# %%
#Saving the model
model.save('model.h5')
#loss: 0.0928 - acc: 0.9333 - val_loss: 0.7667 - val_acc: 0.8333

# %%
#Loading the model
model = load_model('model.h5')

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# Evaluating model on validation data
evaluate = model.evaluate(x_val,y_val)
print(evaluate)
# Out:
# 2/2 [==============================] - 0s 205ms/step - loss: 0.7667 - acc: 0.8333
# [0.7666976451873779, 0.8333333134651184]

# %%
# Testing predictions and the actual label
checkImage = test_images[0:1]
checklabel = test_labels[0:1]

predict = model.predict(np.array(checkImage))

output = { 0:'apple',1:'banana',2:'mixed',3:'orange'}

print("Actual :- ",checklabel)
print("Predicted :- ",output[np.argmax(predict)])
# Out:
# Actual :-  ['banana']
# Predicted :-  banana

# %% [markdown]
# # Testing by Ramkishor

# %%
def show_image(index):
    print(test_labels[index])
    #plt.imshow(test_images[index])
    cv2.imshow('win',test_images[index])
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# Testing predictions and the actual label
def test(index):
    checkImage = test_images[index:index+1]
    checklabel = test_labels[index:index+1]

    predict = model.predict(np.array(checkImage))

    output = { 0:'apple',1:'banana',2:'mixed',3:'orange'}
    #print("Actual :- ",checklabel)
    #print("Predicted :- ",output[np.argmax(predict)])
    
    return checklabel,output[np.argmax(predict)]
    #show_image(index)

# %%
correct_count = 0
incorrect_count = 0
for i in range(10,len(test_images)):
    Actual,Predicted = test(i)

    
    if Actual[0] == Predicted:
        correct_count+=1
        #print(f"{Actual[0]} is predicted as {Predicted}")
        #show_image(i)
    else:
        incorrect_count+=1
        #print(f"{Actual[0]} is predicted as {Predicted}")
        #show_image(i)
print()
print(f"correct_count = {correct_count}")
print(f"incorrect_count = {incorrect_count}")
# Out:
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
#
# correct_count = 42
# incorrect_count = 8
