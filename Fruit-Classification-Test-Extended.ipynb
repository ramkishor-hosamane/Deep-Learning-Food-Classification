# %%
# Importing modules 
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
import cv2

from keras.utils import to_categorical
from keras.layers import Dense,Conv2D,Flatten,MaxPool2D,Dropout,Activation,MaxPooling2D
from keras.models import Sequential
from keras.models import load_model
from sklearn.model_selection import train_test_split

np.random.seed(1)

# %%
# Processing training data
# -> appending images in a list 'train_images'
# -> appending labels in a list 'train_labels'

train_images = []       
train_labels = []
shape = (100,100)  
train_path = 'DataExtended/train_zip/train'

for filename in os.listdir('DataExtended/train_zip/train'):
    if filename.split('.')[1] == 'jpg':
        img = cv2.imread(os.path.join(train_path,filename))
        
        try:
            # Resize all images to a specific shape
            img = cv2.resize(img,shape)

            # Spliting file names and storing the labels for image in list
            train_labels.append(filename.split('_')[0])

            train_images.append(img)
        except:
            pass
# Converting labels into One Hot encoded sparse matrix
train_labels = pd.get_dummies(train_labels).values

# Converting train_images to array
train_images = np.array(train_images)

# Splitting Training data into train and validation dataset
x_train,x_val,y_train,y_val = train_test_split(train_images,train_labels,random_state=1)

# %%
# Processing testing data
# -> appending images in a list 'test_images'
# -> appending labels in a list 'test_labels'
# The test data contains labels as well also we are appending it to a list but we are'nt going to use it while training.

test_images = []
test_labels = []
test_path = 'DataExtended/test_zip/test'

for filename in os.listdir('DataExtended/test_zip/test'):
    if filename.split('.')[1] == 'jpg':
        img = cv2.imread(os.path.join(test_path,filename))
        
        # Spliting file names and storing the labels for image in list
        test_labels.append(filename.split('_')[0])
        
        # Resize all images to a specific shape
        img = cv2.resize(img,shape)
        
        test_images.append(img)
        
# Converting test_images to array
test_images = np.array(test_images)

# %%
# Visualizing Training data
print(train_labels[0])
plt.imshow(train_images[0])
# Out:
# [0 0 1]

# %%
# Visualizing Training data
print(train_labels[4])
plt.imshow(train_images[4])
# Out:
# [0 0 1]

# %%
#Building model 1 using customized convolutional and pooling layers

model = Sequential()

#input_shape is 100*100 since thats the dimension of each of the fruit images
model.add(Conv2D(filters = 32, kernel_size = 2,input_shape=(100,100,3),padding='same'))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 32,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 64,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

model.add(Conv2D(filters = 128,kernel_size = 2,activation= 'relu',padding='same'))
model.add(MaxPooling2D(pool_size=2))

# specifying parameters for fully connected layer
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(150))
model.add(Activation('relu'))
model.add(Dropout(0.4))
model.add(Dense(3,activation = 'softmax'))

# %%
# Model Summary
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 100, 100, 32)      416
# _________________________________________________________________
# activation (Activation)      (None, 100, 100, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 50, 50, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 50, 50, 32)        4128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 25, 25, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 25, 25, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 128)       32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout (Dropout)            (None, 6, 6, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 4608)              0
# _________________________________________________________________
# dense (Dense)                (None, 150)               691350
# _________________________________________________________________
# activation_1 (Activation)    (None, 150)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 3)                 453
# =================================================================
# Total params: 737,499
# Trainable params: 737,499
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Training takes 10 minutes     Hold your horses!!!!!

# %%
from keras.optimizers import SGD, Adam, RMSprop

optimizer = Adam()
model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,
              metrics=['accuracy'])

# %%
# fitting model using above defined layers 
CNN_model = model.fit(x_train,y_train,epochs=50,batch_size=50,validation_data=(x_val,y_val),
        verbose=2, shuffle=True)
# Out:
# Epoch 1/50
# 8/8 - 2s - loss: 35.3829 - accuracy: 0.3967 - val_loss: 1.0216 - val_accuracy: 0.6803
# Epoch 2/50
# 8/8 - 2s - loss: 3.0533 - accuracy: 0.4573 - val_loss: 1.0857 - val_accuracy: 0.7213
# Epoch 3/50
# 8/8 - 2s - loss: 1.0771 - accuracy: 0.6309 - val_loss: 0.7371 - val_accuracy: 0.7131
# Epoch 4/50
# 8/8 - 2s - loss: 0.6658 - accuracy: 0.7135 - val_loss: 0.5024 - val_accuracy: 0.8115
# Epoch 5/50
# 8/8 - 2s - loss: 0.4864 - accuracy: 0.7906 - val_loss: 0.5398 - val_accuracy: 0.7541
# Epoch 6/50
# 8/8 - 2s - loss: 0.4448 - accuracy: 0.8044 - val_loss: 0.5694 - val_accuracy: 0.7623
# Epoch 7/50
# 8/8 - 2s - loss: 0.3482 - accuracy: 0.8430 - val_loss: 0.5053 - val_accuracy: 0.8033
# Epoch 8/50
# 8/8 - 2s - loss: 0.3031 - accuracy: 0.8788 - val_loss: 0.4841 - val_accuracy: 0.8443
# Epoch 9/50
# 8/8 - 2s - loss: 0.2926 - accuracy: 0.8760 - val_loss: 0.4037 - val_accuracy: 0.8197
# Epoch 10/50
# 8/8 - 2s - loss: 0.2314 - accuracy: 0.9036 - val_loss: 0.4618 - val_accuracy: 0.8115
# Epoch 11/50
# 8/8 - 2s - loss: 0.1862 - accuracy: 0.9256 - val_loss: 0.4602 - val_accuracy: 0.8279
# Epoch 12/50
# 8/8 - 2s - loss: 0.1581 - accuracy: 0.9421 - val_loss: 0.4825 - val_accuracy: 0.8525
# Epoch 13/50
# 8/8 - 2s - loss: 0.1739 - accuracy: 0.9284 - val_loss: 0.4568 - val_accuracy: 0.8689
# Epoch 14/50
# 8/8 - 2s - loss: 0.1592 - accuracy: 0.9339 - val_loss: 0.5074 - val_accuracy: 0.8361
# Epoch 15/50
# 8/8 - 2s - loss: 0.1648 - accuracy: 0.9339 - val_loss: 0.6278 - val_accuracy: 0.8443
# Epoch 16/50
# 8/8 - 2s - loss: 0.1299 - accuracy: 0.9587 - val_loss: 0.6871 - val_accuracy: 0.8525
# Epoch 17/50
# 8/8 - 2s - loss: 0.0713 - accuracy: 0.9835 - val_loss: 0.6991 - val_accuracy: 0.8689
# Epoch 18/50
# 8/8 - 2s - loss: 0.0665 - accuracy: 0.9780 - val_loss: 0.8128 - val_accuracy: 0.8770
# Epoch 19/50
# 8/8 - 2s - loss: 0.0787 - accuracy: 0.9780 - val_loss: 0.7582 - val_accuracy: 0.8607
# Epoch 20/50
# 8/8 - 2s - loss: 0.0520 - accuracy: 0.9807 - val_loss: 0.7794 - val_accuracy: 0.8770
# Epoch 21/50
# 8/8 - 2s - loss: 0.0426 - accuracy: 0.9890 - val_loss: 0.8061 - val_accuracy: 0.8689
# Epoch 22/50
# 8/8 - 2s - loss: 0.0385 - accuracy: 0.9835 - val_loss: 0.7529 - val_accuracy: 0.8525
# Epoch 23/50
# 8/8 - 2s - loss: 0.0576 - accuracy: 0.9862 - val_loss: 0.7478 - val_accuracy: 0.8197
# Epoch 24/50
# 8/8 - 2s - loss: 0.0444 - accuracy: 0.9862 - val_loss: 0.7436 - val_accuracy: 0.8770
# Epoch 25/50
# 8/8 - 2s - loss: 0.0260 - accuracy: 0.9972 - val_loss: 0.6041 - val_accuracy: 0.8934
# Epoch 26/50
# 8/8 - 2s - loss: 0.0395 - accuracy: 0.9862 - val_loss: 0.6835 - val_accuracy: 0.9016
# Epoch 27/50
# 8/8 - 2s - loss: 0.0252 - accuracy: 0.9917 - val_loss: 0.7181 - val_accuracy: 0.8852
# Epoch 28/50
# 8/8 - 2s - loss: 0.0270 - accuracy: 0.9945 - val_loss: 0.7506 - val_accuracy: 0.8770
# Epoch 29/50
# 8/8 - 2s - loss: 0.0131 - accuracy: 0.9972 - val_loss: 0.7365 - val_accuracy: 0.8607
# Epoch 30/50
# 8/8 - 2s - loss: 0.0555 - accuracy: 0.9697 - val_loss: 0.6621 - val_accuracy: 0.8852
# Epoch 31/50
# 8/8 - 2s - loss: 0.0519 - accuracy: 0.9780 - val_loss: 0.6197 - val_accuracy: 0.8852
# Epoch 32/50
# 8/8 - 2s - loss: 0.0395 - accuracy: 0.9862 - val_loss: 0.7392 - val_accuracy: 0.8852
# Epoch 33/50
# 8/8 - 2s - loss: 0.0392 - accuracy: 0.9862 - val_loss: 0.9401 - val_accuracy: 0.9016
# Epoch 34/50
# 8/8 - 2s - loss: 0.0214 - accuracy: 0.9945 - val_loss: 1.0011 - val_accuracy: 0.8934
# Epoch 35/50
# 8/8 - 2s - loss: 0.0317 - accuracy: 0.9807 - val_loss: 0.6522 - val_accuracy: 0.9180
# Epoch 36/50
# 8/8 - 2s - loss: 0.0508 - accuracy: 0.9835 - val_loss: 0.7122 - val_accuracy: 0.8934
# Epoch 37/50
# 8/8 - 2s - loss: 0.0117 - accuracy: 1.0000 - val_loss: 0.6564 - val_accuracy: 0.9098
# Epoch 38/50
# 8/8 - 2s - loss: 0.0119 - accuracy: 0.9972 - val_loss: 0.8212 - val_accuracy: 0.8770
# Epoch 39/50
# 8/8 - 2s - loss: 0.0139 - accuracy: 0.9945 - val_loss: 0.8439 - val_accuracy: 0.9016
# Epoch 40/50
# 8/8 - 2s - loss: 0.0331 - accuracy: 0.9862 - val_loss: 0.8115 - val_accuracy: 0.8852
# Epoch 41/50
# 8/8 - 2s - loss: 0.0148 - accuracy: 0.9945 - val_loss: 1.0554 - val_accuracy: 0.9098
# Epoch 42/50
# 8/8 - 2s - loss: 0.0159 - accuracy: 0.9945 - val_loss: 0.8074 - val_accuracy: 0.9098
# Epoch 43/50
# 8/8 - 2s - loss: 0.0137 - accuracy: 0.9972 - val_loss: 0.8975 - val_accuracy: 0.9180
# Epoch 44/50
# 8/8 - 2s - loss: 0.0043 - accuracy: 1.0000 - val_loss: 1.0502 - val_accuracy: 0.8770
# Epoch 45/50
# 8/8 - 2s - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.1304 - val_accuracy: 0.8770
# Epoch 46/50
# 8/8 - 2s - loss: 0.0053 - accuracy: 1.0000 - val_loss: 1.1685 - val_accuracy: 0.8852
# Epoch 47/50
# 8/8 - 2s - loss: 0.0827 - accuracy: 0.9697 - val_loss: 0.6329 - val_accuracy: 0.9016
# Epoch 48/50
# 8/8 - 2s - loss: 0.0867 - accuracy: 0.9752 - val_loss: 0.9532 - val_accuracy: 0.8770
# Epoch 49/50
# 8/8 - 2s - loss: 0.0592 - accuracy: 0.9890 - val_loss: 0.8768 - val_accuracy: 0.8934
# Epoch 50/50
# 8/8 - 2s - loss: 0.0791 - accuracy: 0.9835 - val_loss: 0.7481 - val_accuracy: 0.8852

# %%
#Saving the model
model.save('newmodel.h5')
#loss: 0.0928 - acc: 0.9333 - val_loss: 0.7667 - val_acc: 0.8333

# %%
#Loading the model
model = load_model('newmodel.h5')
history  = CNN_model

# %%
# Evaluating model on validation data
evaluate = model.evaluate(x_val,y_val)
print(evaluate)
# Out:
# 4/4 [==============================] - 0s 24ms/step - loss: 0.7481 - accuracy: 0.8852
# [0.7480696439743042, 0.8852459192276001]

# %%
# Testing predictions and the actual label
checkImage = test_images[0:1]
checklabel = test_labels[0:1]

predict = model.predict(np.array(checkImage))

output = { 0:'apple',1:'banana',2:'orange'}

print("Actual :- ",checklabel)
print("Predicted :- ",output[np.argmax(predict)])
# Out:
# Actual :-  ['banana']
# Predicted :-  banana

# %% [markdown]
# # Testing by Ramkishor

# %%
def show_image(index):
    print(test_labels[index])
    #plt.imshow(test_images[index])
    cv2.imshow('win',test_images[index])
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
# Testing predictions and the actual label
def test(index):
    checkImage = test_images[index:index+1]
    checklabel = test_labels[index:index+1]

    predict = model.predict(np.array(checkImage))

    output = { 0:'apple',1:'banana',2:'orange'}
    #print("Actual :- ",checklabel)
    #print("Predicted :- ",output[np.argmax(predict)])
    
    return checklabel,output[np.argmax(predict)]
    #show_image(index)

# %%
correct_count = 0
incorrect_count = 0
for i in range(10,len(test_images)):
    Actual,Predicted = test(i)

    
    if Actual[0] == Predicted:
        correct_count+=1
        #print(f"{Actual[0]} is predicted as {Predicted}")
        #show_image(i)
    else:
        incorrect_count+=1
        #print(f"{Actual[0]} is predicted as {Predicted}")
        #show_image(i)
print()
print(f"correct_count = {correct_count}")
print(f"incorrect_count = {incorrect_count}")
# Out:
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
# apple is predicted as apple
# apple
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# banana is predicted as banana
# banana
# banana is predicted as banana
# banana
# orange is predicted as orange
# orange
# apple is predicted as apple
# apple
#
# correct_count = 43
# incorrect_count = 6

# %%
NewTestPath = 'NewTestData'
my_test_images=[]
my_test_labels=[]

for filename in os.listdir(NewTestPath):
        img = cv2.imread(os.path.join(NewTestPath,filename))
        
        # Resize all images to a specific shape
        img = cv2.resize(img,shape)
                
        # Spliting file names and storing the labels for image in list
        my_test_labels.append(filename.split('_')[0])
        

        my_test_images.append(img)


def test(index):
    checkImage = my_test_images[index:index+1]
    Actual = my_test_labels[index]
    predict = model.predict(np.array(checkImage))

    output = { 0:'apple',1:'banana',2:'orange'}
    #print("Actual :- ",checklabel)
    #print("Predicted :- ",output[np.argmax(predict)])
    
    return Actual,output[np.argmax(predict)]
    #show_image(index)
def show_image(index):
    #plt.imshow(test_images[index])
    cv2.imshow('win',my_test_images[i])
    cv2.waitKey(0)
    cv2.destroyAllWindows()


for i in range(len(my_test_images)):
    Actual,Predicted = test(i)
    print(f"{Actual} is predicted as {Predicted}")
    show_image(i)
# Out:
# orange is predicted as apple
# banana is predicted as banana
# orange is predicted as banana
# orange is predicted as banana
# banana is predicted as banana
# orange is predicted as banana
# banana is predicted as apple
# apple is predicted as apple
# banana is predicted as banana
# orange is predicted as banana
# banana is predicted as orange
# apple is predicted as apple
